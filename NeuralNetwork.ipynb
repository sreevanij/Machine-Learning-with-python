# %% [raw]
# Using TensorFlow to train and test Fashion Minst dataset

# %%
import tensorflow as tf

# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
data = keras.datasets.fashion_mnist
(train_images,train_labels),(test_images,test_labels) = data.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
train_images = train_images/255
test_images = test_images/255
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128,activation='relu'),
    keras.layers.Dense(10,activation='softmax')
])

# %%
model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# %%
model.fit(train_images,train_labels,epochs=7)
#test_loss,test_acc = model.evaluate(test_images,test_labels)
#print(test_acc)
# Out:
# Train on 60000 samples
# Epoch 1/7
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.1794 - accuracy: 0.9326
# Epoch 2/7
# 60000/60000 [==============================] - 4s 70us/sample - loss: 0.1767 - accuracy: 0.9325
# Epoch 3/7
# 60000/60000 [==============================] - 4s 70us/sample - loss: 0.1722 - accuracy: 0.9347
# Epoch 4/7
# 60000/60000 [==============================] - 4s 70us/sample - loss: 0.1680 - accuracy: 0.9364
# Epoch 5/7
# 60000/60000 [==============================] - 4s 70us/sample - loss: 0.1632 - accuracy: 0.9379
# Epoch 6/7
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.1612 - accuracy: 0.9391
# Epoch 7/7
# 60000/60000 [==============================] - 4s 70us/sample - loss: 0.1569 - accuracy: 0.9406

# %%
prediction = model.predict(test_images)
#let's test few images
for i in range(5):
    plt.grid(False)
    plt.imshow(test_images[i],cmap=plt.cm.binary)
    plt.xlabel("Actual "+class_names[test_labels[i]])
    plt.title("prediction "+class_names[np.argmax(prediction[i])])
    plt.show()
