# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
train_df = pd.read_csv("bike-sharing-demand/train.csv",parse_dates=['datetime'])

# %%
train_df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
test_df = pd.read_csv("bike-sharing-demand/test.csv",parse_dates=['datetime'])

test_df.head()
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
columns = ['count', 'season', 'holiday', 'workingday', 'weather', 'temp',
       'atemp', 'humidity', 'windspeed', 'year', 'month', 'day', 'dayofweek','hour']

cols_normalize = ['temp','atemp','humidity','windspeed']

# %%
def add_features(df):
    df['year'] = df['datetime'].dt.year
    df['month'] = df['datetime'].dt.month
    df['day'] = df['datetime'].dt.day
    df['dayofweek']=df['datetime'].dt.day
    df['hour'] = df['datetime'].dt.hour

# %%
add_features(train_df)
add_features(test_df)

# %%
train_df['count']=train_df['count'].map(np.log1p)

# %%
train_df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered     count  year  month  day  \
# 0        81        0.0       3          13  2.833213  2011      1    1
# 1        80        0.0       8          32  3.713572  2011      1    1
# 2        80        0.0       5          27  3.496508  2011      1    1
# 3        75        0.0       3          10  2.639057  2011      1    1
# 4        75        0.0       0           1  0.693147  2011      1    1
#
#    dayofweek  hour
# 0          1     0
# 1          1     1
# 2          1     2
# 3          1     3
# 4          1     4

# %%
scaler = StandardScaler()

# %%
scaler.fit(train_df[cols_normalize])
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
train_df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered     count  year  month  day  \
# 0        81        0.0       3          13  2.833213  2011      1    1
# 1        80        0.0       8          32  3.713572  2011      1    1
# 2        80        0.0       5          27  3.496508  2011      1    1
# 3        75        0.0       3          10  2.639057  2011      1    1
# 4        75        0.0       0           1  0.693147  2011      1    1
#
#    dayofweek  hour
# 0          1     0
# 1          1     1
# 2          1     2
# 3          1     3
# 4          1     4

# %%
pca = PCA(n_components=0.9)
pca.fit(train_df[cols_normalize])
# Out:
# PCA(copy=True, iterated_power='auto', n_components=0.9, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
print(pca.n_components) #variance
pca.n_components_
# Out:
# 0.9
# 3

# %%
train_df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered     count  year  month  day  \
# 0        81        0.0       3          13  2.833213  2011      1    1
# 1        80        0.0       8          32  3.713572  2011      1    1
# 2        80        0.0       5          27  3.496508  2011      1    1
# 3        75        0.0       3          10  2.639057  2011      1    1
# 4        75        0.0       0           1  0.693147  2011      1    1
#
#    dayofweek  hour
# 0          1     0
# 1          1     1
# 2          1     2
# 3          1     3
# 4          1     4

# %%
transformed_data = pca.transform(train_df[cols_normalize])
transformed_data
# Out:
# array([[-21.50215306,  12.13273921, -10.59877225],
#        [-20.56621054,  13.27481689, -10.84606528],
#        [-20.56621054,  13.27481689, -10.84606528],
#        ...,
#        [  0.77997275,  10.13067661,   1.28634827],
#        [ -0.59582495,   8.28205298,  -7.50714907],
#        [ -5.10643955,   9.4760491 ,  -3.84316822]])

# %%
cols = ['count', 'season', 'holiday', 'workingday', 'weather','year', 'month', 'day', 'dayofweek','hour']
cols2 = ['count', 'season', 'holiday', 'workingday', 'weather','year', 'month', 'day', 'dayofweek','hour']

for i in range(pca.n_components_):
    cols.append("component_"+str(i))

# %%
cols
# Out:
# ['count',
#  'season',
#  'holiday',
#  'workingday',
#  'weather',
#  'year',
#  'month',
#  'day',
#  'dayofweek',
#  'hour',
#  'component_0',
#  'component_1',
#  'component_2']

# %%
final_df = pd.DataFrame(columns=cols)

# %%
int_df = pd.DataFrame(transformed_data,columns=['component_0','component_1','component_2'])
int_df.head()
# Out:
#    component_0  component_1  component_2
# 0   -21.502153    12.132739   -10.598772
# 1   -20.566211    13.274817   -10.846065
# 2   -20.566211    13.274817   -10.846065
# 3   -15.583428    12.325531   -11.563773
# 4   -15.583428    12.325531   -11.563773

# %%
for col in cols2:
    final_df[col] = train_df[col]

final_df.head()
# Out:
#       count  season  holiday  workingday  weather  year  month  day  \
# 0  2.833213       1        0           0        1  2011      1    1
# 1  3.713572       1        0           0        1  2011      1    1
# 2  3.496508       1        0           0        1  2011      1    1
# 3  2.639057       1        0           0        1  2011      1    1
# 4  0.693147       1        0           0        1  2011      1    1
#
#    dayofweek  hour component_0 component_1 component_2
# 0          1     0         NaN         NaN         NaN
# 1          1     1         NaN         NaN         NaN
# 2          1     2         NaN         NaN         NaN
# 3          1     3         NaN         NaN         NaN
# 4          1     4         NaN         NaN         NaN

# %%
final_df['component_0'] = int_df['component_0']
final_df['component_1'] = int_df['component_1']
final_df['component_2'] = int_df['component_2']

final_df.head()
# Out:
#       count  season  holiday  workingday  weather  year  month  day  \
# 0  2.833213       1        0           0        1  2011      1    1
# 1  3.713572       1        0           0        1  2011      1    1
# 2  3.496508       1        0           0        1  2011      1    1
# 3  2.639057       1        0           0        1  2011      1    1
# 4  0.693147       1        0           0        1  2011      1    1
#
#    dayofweek  hour  component_0  component_1  component_2
# 0          1     0   -21.502153    12.132739   -10.598772
# 1          1     1   -20.566211    13.274817   -10.846065
# 2          1     2   -20.566211    13.274817   -10.846065
# 3          1     3   -15.583428    12.325531   -11.563773
# 4          1     4   -15.583428    12.325531   -11.563773

# %%
import xgboost as xgb

x_train = final_df.iloc[:,1:]
y_train = final_df.iloc[:,0]

# %%
y_train
# Out:
# 0        2.833213
# 1        3.713572
# 2        3.496508
# 3        2.639057
# 4        0.693147
#            ...
# 10881    5.820083
# 10882    5.488938
# 10883    5.129899
# 10884    4.867534
# 10885    4.488636
# Name: count, Length: 10886, dtype: float64

# %%
regressor = xgb.XGBRegressor(max_depth=5,n_estimators=150)

regressor
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=None, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=None, max_delta_step=None, max_depth=5,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=150, n_jobs=None, num_parallel_tree=None,
#              objective='reg:squarederror', random_state=None, reg_alpha=None,
#              reg_lambda=None, scale_pos_weight=None, subsample=None,
#              tree_method=None, validate_parameters=None, verbosity=None)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=5,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=150, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
test_df = pd.read_csv("bike-sharing-demand/test.csv",parse_dates=['datetime'])

# %%
test_df.head()
add_features(test_df)

# %%
scaler = StandardScaler()
scaler.fit(test_df[cols_normalize])

pca = PCA(n_components=0.9)
pca.fit(test_df[cols_normalize])
# Out:
# PCA(copy=True, iterated_power='auto', n_components=0.9, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
transformed_data = pca.transform(test_df[cols_normalize])

# %%
inttest_df = pd.DataFrame(transformed_data,columns=['component_0','component_1','component_2'])

test_df['component_0'] = inttest_df['component_0']
test_df['component_1'] = inttest_df['component_1']
test_df['component_2'] = inttest_df['component_2']

# %%
final_test_df = test_df.iloc[:,1:]
final_test_df.head()
# Out:
#    season  holiday  workingday  weather   temp   atemp  humidity  windspeed  \
# 0       1        0           1        1  10.66  11.365        56    26.0027
# 1       1        0           1        1  10.66  13.635        56     0.0000
# 2       1        0           1        1  10.66  13.635        56     0.0000
# 3       1        0           1        1  10.66  12.880        56    11.0014
# 4       1        0           1        1  10.66  12.880        56    11.0014
#
#    component_0  component_1  component_2  year  month  day  dayofweek  hour
# 0     8.573959    17.748251    10.713223  2011      1   20         20     0
# 1     5.504756    13.487307   -14.841451  2011      1   20         20     1
# 2     5.504756    13.487307   -14.841451  2011      1   20         20     2
# 3     6.813134    15.139400    -4.019443  2011      1   20         20     3
# 4     6.813134    15.139400    -4.019443  2011      1   20         20     4

# %%
final_test_df = final_test_df.drop(['temp','atemp','humidity','windspeed'],axis=1)

# %%
re_index = ['season', 'holiday', 'workingday', 'weather', 'year', 'month', 'day', 'dayofweek', 'hour', 'component_0', 'component_1', 'component_2']
final_test_df=final_test_df.reindex(columns=re_index)

final_pred = regressor.predict(final_test_df)

# %%
final_pred
# Out:
# array([2.3796558, 1.4996266, 0.9611697, ..., 4.690411 , 4.7823687,
#        4.525414 ], dtype=float32)

# %%
test_df['count'] = np.expm1(final_pred)

# %%
test_df.head(2)
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
#
#    humidity  windspeed  component_0  component_1  component_2  year  month  \
# 0        56    26.0027     8.573959    17.748251    10.713223  2011      1
# 1        56     0.0000     5.504756    13.487307   -14.841451  2011      1
#
#    day  dayofweek  hour     count
# 0   20         20     0  9.801185
# 1   20         20     1  3.480016

# %%
test_df[test_df['count']<0]
# Out:
# Empty DataFrame
# Columns: [datetime, season, holiday, workingday, weather, temp, atemp, humidity, windspeed, component_0, component_1, component_2, year, month, day, dayofweek, hour, count]
# Index: []

# %%
test_df.head(2)
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
#
#    humidity  windspeed  component_0  component_1  component_2  year  month  \
# 0        56    26.0027     8.573959    17.748251    10.713223  2011      1
# 1        56     0.0000     5.504756    13.487307   -14.841451  2011      1
#
#    day  dayofweek  hour     count
# 0   20         20     0  9.801185
# 1   20         20     1  3.480016

# %%
test_df[['datetime','count']].to_csv('predicted_count.csv',index=False)
